# %% [markdown]
# <a href="https://colab.research.google.com/github/z-hassan01/CRD-Python-2026/blob/main/practice_16_01_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Methods Applicable to List'''

# Methods to add items
list.append()
list.extend()
list.insert()
list.extend()
# Methods to remove item
list.remove()
list.pop()
list.clear()
# Other Methods
list.count()
list.index()
list.sort()
list.reverse()
list.copy()

'''Methods Applicable to Tuple'''
tuple.count()
tuple.index()

'''Methods Applicable to Set'''

# %%
demo_list=[2008201,2008206,2008226,2008235,2008237,2008238,2008253]
demo_list.append(2008246) #Adds an element at the end of the list
demo_list
# Out:
# [2008201, 2008206, 2008226, 2008235, 2008237, 2008238, 2008253, 2008246]

# %%
demo_list.remove(2008206)  #Removes the item with the specified value
demo_list
# Out:
# [2008201, 2008226, 2008235, 2008237, 2008238, 2008253, 2008246]

# %%
demo_list.count(2008201) #Returns the number of occurrences of a value.
# Out:
# 1

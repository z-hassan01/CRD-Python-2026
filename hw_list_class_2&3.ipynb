# %% [markdown]
# <a href="https://colab.research.google.com/github/z-hassan01/CRD-Python-2026/blob/main/hw_list_class_2%263.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# এশিয়া মহাদেশের মধ্যে যতগুলো দেশ আছে তাদের একটা লিস্ট তৈরী করবেন। তারপর ইনপুট ফাংশন ব্যবহার করে একটা ইনপুট নিবেন। উক্ত ইনপুট ডাটাটি লিস্টের মধ্যে আছে কিনা সেটা চেক করবেন। যদি কোড সঠিকভাবে কাজ করে তাহলে একটা স্ক্রিনশট নিয়ে জমা দিবেন।

# %%
asian_countries=['Afghanistan','Palestine','China','Thailand','Malaysia','Japan','South Korea','Singapore','Indonesia',"Taiwan",'Saudi Arabia','Qatar']

asian_countries.append('Bangladesh')

print('Bangladesh' in asian_countries)
asian_countries
# Out:
# True
# ['Afghanistan',
#  'Palestine',
#  'China',
#  'Thailand',
#  'Malaysia',
#  'Japan',
#  'South Korea',
#  'Singapore',
#  'Indonesia',
#  'Taiwan',
#  'Saudi Arabia',
#  'Qatar',
#  'Bangladesh']
